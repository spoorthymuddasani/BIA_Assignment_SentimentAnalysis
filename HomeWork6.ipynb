# %%
#Installing libraries

# %%
pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Defining the imports 

#The import statement "from pylab import rcParams" allows you to access the "rcParams" module from the "pylab" library directly in your code. 
#"rcParams" is a module that contains various settings and parameters for plotting figures using matplotlib, a popular plotting library in Python. By importing "rcParams" using this statement, you can use its various properties and methods to customize the appearance of your plots, such as adjusting the size of the figure, changing the font size of labels, and so on.
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

#The import statement "from textblob import TextBlob" allows you to access the "TextBlob" class from the "textblob" library directly in your code. 
#"TextBlob" is a popular Python library for processing textual data, such as natural language text. By importing "TextBlob" using this statement, you can create instances of the "TextBlob" class, which can then be used to perform various natural language processing tasks, such as sentiment analysis, part-of-speech tagging, and text classification.
from textblob import TextBlob

#The import statement "import sys" allows you to access the "sys" module directly in your code. "sys" is a built-in Python module that provides access to various system-specific parameters and functions. 
#By importing "sys" using this statement, you can use its various properties and methods to interact with the Python interpreter and the underlying operating system, such as accessing command-line arguments, modifying the Python path, and exiting the program.
import sys

#The import statement "import tweepy" allows you to access the "tweepy" library directly in your code. 
#"tweepy" is a popular Python library for interacting with the Twitter API. By importing "tweepy" using this statement, you can use its various classes and methods to authenticate with the Twitter API, retrieve tweets, search for users, and perform other actions related to Twitter data.
import tweepy

#The import statement "import matplotlib.pyplot as plt" allows you to access the "pyplot" module from the "matplotlib" library directly in your code, and assign it an alias "plt" for convenience. "matplotlib" is a popular Python library for creating visualizations, such as plots and charts. 
#By importing "pyplot" using this statement, you can use its various functions to create and customize plots, such as setting the plot title, labeling the x- and y-axes, adding legends, and so on. The alias "plt" is commonly used to make code shorter and more readable.
import matplotlib.pyplot as plt

#The import statement "import pandas as pd" allows you to access the "pandas" library directly in your code, and assign it an alias "pd" for convenience. "pandas" is a popular Python library for data manipulation and analysis. 
#By importing "pandas" using this statement, you can use its various classes and functions to read and write data in various formats, manipulate data frames and series, filter and aggregate data, and perform other data-related tasks. The alias "pd" is commonly used to make code shorter and more readable.
import pandas as pd

#The import statement "import numpy as np" allows you to access the "numpy" library directly in your code, and assign it an alias "np" for convenience. "numpy" is a popular Python library for numerical computing and data analysis. 
#By importing "numpy" using this statement, you can use its various classes and functions to perform mathematical and statistical operations on arrays and matrices, manipulate and transform data, generate random numbers, and so on. The alias "np" is commonly used to make code shorter and more readable.
import numpy as np

#The import statement "import os" allows you to access the "os" module directly in your code. "os" is a built-in Python module that provides a way to interact with the operating system. 
#By importing "os" using this statement, you can use its various functions to perform operating system related tasks, such as navigating through directories, creating and deleting files and directories, retrieving environment variables, and so on.
import os

#The import statement "import nltk" allows you to access the "nltk" library directly in your code. "nltk" (Natural Language Toolkit) is a popular Python library for natural language processing tasks, such as tokenization, stemming, lemmatization, part-of-speech tagging, and parsing. 
#By importing "nltk" using this statement, you can use its various classes and functions to perform these tasks on text data. However, some functionalities of "nltk" may require additional data to be downloaded separately using the "nltk.download()" function.
import nltk

#The import statement "import pycountry" allows you to access the "pycountry" library directly in your code. "pycountry" is a Python library that provides a way to work with ISO databases related to countries, subdivisions, and currencies. 
#By importing "pycountry" using this statement, you can use its various functions and classes to retrieve information about countries, such as their names, codes, currencies, and subdivisions. This library is useful when working with data that involves geographical information or internationalization.
import pycountry

#The import statement "import re" allows you to access the "re" module directly in your code. "re" is a built-in Python module that provides regular expression matching operations. 
#By importing "re" using this statement, you can use its various functions and methods to search and manipulate text data using regular expressions. Regular expressions are a powerful way to search for patterns in strings, and can be used to perform tasks such as validating data, extracting information, and cleaning text data.
import re

#The import statement "import string" allows you to access the "string" module directly in your code. "string" is a built-in Python module that provides various constants, functions, and classes for working with strings. 
#By importing "string" using this statement, you can use its various constants, such as "string.ascii_letters", "string.digits", "string.punctuation", and "string.whitespace", to perform tasks such as generating random strings, cleaning text data, and formatting strings. The "string" module also provides some helper functions for working with templates, formatting, and encoding.
import string

#The import statement "from wordcloud import WordCloud, STOPWORDS" allows you to access the "WordCloud" class and the "STOPWORDS" set directly in your code from the "wordcloud" library. "wordcloud" is a popular Python library for creating word clouds, which are visual representations of the most frequently occurring words in a text corpus. 
#By importing "WordCloud" using this statement, you can create word cloud objects and customize their appearance, such as setting the size, color, font, and shape. By importing "STOPWORDS" using this statement, you can access a predefined set of common English stop words that can be removed from the text before creating the word cloud, such as "the", "a", "an", "and", and so on.
from wordcloud import WordCloud, STOPWORDS

#The import statement "from PIL import Image" allows you to access the "Image" class directly in your code from the "PIL" (Python Imaging Library) library. "PIL" is a Python library for working with images, such as opening, creating, modifying, and saving them. 
#By importing "Image" using this statement, you can create an Image object and manipulate it using various methods and attributes provided by the "Image" class. This library supports various image file formats, such as JPEG, PNG, BMP, TIFF, and GIF, and provides functionalities for resizing, cropping, rotating, filtering, and enhancing images.
from PIL import Image

#The import statement "from nltk.sentiment.vader import SentimentIntensityAnalyzer" allows you to access the "SentimentIntensityAnalyzer" class directly in your code from the "nltk.sentiment.vader" module in the "nltk" library. "nltk.sentiment.vader" is a sub-module of the "nltk" library that provides a pre-trained sentiment analysis tool called the VADER (Valence Aware Dictionary and sEntiment Reasoner) sentiment analyzer. 
#By importing "SentimentIntensityAnalyzer" using this statement, you can create a "SentimentIntensityAnalyzer" object and use its "polarity_scores()" method to analyze the sentiment of a piece of text. 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#The import statement "from langdetect import detect" allows you to access the "detect" function directly in your code from the "langdetect" library. "langdetect" is a Python library for language detection, which means automatically identifying the language of a given text. 
#By importing "detect" using this statement, you can use the "detect()" function to detect the language of a piece of text by analyzing its character n-gram frequencies and comparing them to a pre-trained language profile database. The "detect()" function returns a two-letter language code representing the detected language, such as "en" for English, "fr" for French, "de" for German, and so on.
from langdetect import detect

#The import statement "from nltk.stem import SnowballStemmer" allows you to access the "SnowballStemmer" class directly in your code from the "nltk.stem" module in the "nltk" library. "nltk.stem" is a sub-module of the "nltk" library that provides various stemmers for different languages, which means reducing a word to its base or root form by removing its suffixes. 
#By importing "SnowballStemmer" using this statement, you can create a "SnowballStemmer" object and use its "stem()" method to stem a word. The "SnowballStemmer" class is based on the Snowball stemming algorithm, which is a widely used and effective algorithm for stemming English words and some other languages.
from nltk.stem import SnowballStemmer

#The import statement "from nltk.sentiment.vader import SentimentIntensityAnalyzer" allows you to access the "SentimentIntensityAnalyzer" class directly in your code from the "nltk.sentiment.vader" module in the "nltk" library. "nltk.sentiment.vader" is a sub-module of the "nltk" library that provides a pre-trained sentiment analysis tool called the VADER (Valence Aware Dictionary and sEntiment Reasoner) sentiment analyzer. 
#By importing "SentimentIntensityAnalyzer" using this statement, you can create a "SentimentIntensityAnalyzer" object and use its "polarity_scores()" method to analyze the sentiment of a piece of text. The "polarity_scores()" method returns a dictionary with four scores indicating the positive, negative, neutral, and compound sentiment scores of the text, where the compound score is a normalized and weighted composite score of the other three scores.
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#The import statement "from sklearn.feature_extraction.text import CountVectorizer" allows you to access the "CountVectorizer" class directly in your code from the "sklearn.feature_extraction.text" module in the "scikit-learn" library. "sklearn.feature_extraction.text" is a sub-module of the "scikit-learn" library that provides various utilities for extracting features from text data, including the "CountVectorizer" class for creating a bag-of-words representation of text data. 
#By importing "CountVectorizer" using this statement, you can create a "CountVectorizer" object and use its "fit_transform()" method to convert a collection of text documents into a matrix of token counts. The resulting matrix can be used as input to various machine learning models for text classification, clustering, or other tasks.
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Authentication

twitterApiKey = "2CJbp8m7Rg26LtZEKAeVXWceG"
twitterApiSecret = "IbULWKlS0uvhLnMTcFkzvMjDfZUcBM6eVbdLYMUbNafhieX8Y6"
twitterApiAccessToken = "1119095264961126402-8QDK0FvTjGmV7w1hUtGsTyCyH77bNE"
twitterApiAccessTokenSecret = "unheMaBnZsHrcBt3mK1bE8Ib4wtE3tPtAwSA65Y0zWIK0"

# %%
#Auth validation

auth = tweepy.OAuthHandler(twitterApiKey, twitterApiSecret)
auth.set_access_token(twitterApiAccessToken, twitterApiAccessTokenSecret)
twetterApi = tweepy.API(auth)

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))


tweets = tweepy.Cursor(twetterApi.search_tweets, q=keyword).items(noOfTweet)
positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []



for tweet in tweets:
    
    #print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search:  UCM
# Please enter how many tweets to analyze:  500

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)


print("Total Number of Tweets ",len(tweet_list))
print("Positive Tweets: ",len(positive_list))
print("Negative Tweets: ", len(negative_list))
print("Neutral Tweets: ",len(neutral_list))
# Out:
# Total Number of Tweets  500
# Positive Tweets:  79
# Negative Tweets:  70
# Neutral Tweets:  351

# %%
tweet_list
# Out:
#                                                      0
# 0    La mejor película post-Endgame junto con una d...
# 1    RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 2    RT @CristianRau9: La cosecha en Enjambre: feri...
# 3    RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 4    👍me encanta este video: Guardianes de la Galax...
# ..                                                 ...
# 495  RT @Indie5051: Oficialmente la mejor trilogía ...
# 496  RT @ALEXRAM48938815: Hoy hace un AÑO se estren...
# 497  RT @Indie5051: Oficialmente la mejor trilogía ...
# 498                @JamesGunn Thank you for all in UCM
# 499  RT @HenryOmarVC1: La @ucmvccu presente jóvenes...
#
# [500 rows x 1 columns]

# %%
#Creating PieCart

labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'purple', 'orange']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list.drop_duplicates(inplace = True)

# %%
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
tw_list
# Out:
#                                                      0  \
# 0    La mejor película post-Endgame junto con una d...
# 1    RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 2    RT @CristianRau9: La cosecha en Enjambre: feri...
# 4    👍me encanta este video: Guardianes de la Galax...
# 5    RT @Indie5051: Oficialmente la mejor trilogía ...
# ..                                                 ...
# 483  @gabrielbatcave Talvez até quando os X-men for...
# 485  Bradley Cooper actuando como Rocket Raccoon en...
# 487  @McMantiko01 @Indie5051 The dark knight sola e...
# 494  Nova imagem oficial de 'Invasão  Secreta'\n\n#...
# 498                @JamesGunn Thank you for all in UCM
#
#                                                   text
# 0    La mejor película post-Endgame junto con una d...
# 1    RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 2    RT @CristianRau9: La cosecha en Enjambre: feri...
# 4    👍me encanta este video: Guardianes de la Galax...
# ...

# %%
#Cleaning Text (RT, Punctuation etc)

#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   La mejor película post-Endgame junto con una d...
# 1   RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 2   RT @CristianRau9: La cosecha en Enjambre: feri...
# 4   👍me encanta este video: Guardianes de la Galax...
# 5   RT @Indie5051: Oficialmente la mejor trilogía ...
# 6   @Indie5051 Me impresiona darme cuenta que a mu...
# 7   El Capitán América del UCM  ya mola de por sí,...
# 9   @atletista1989 Y sabe mucho más de cómics que ...
# 10  RT @thxchosnone: Guardianes de la Galaxia tien...
# 11  RT @croquet_13: Btw, el Alto Evolucionador se ...
#
#                                                  text
# 0   la mejor pel cula post endgame junto con una d...
# 1    ni se estrena y ya la odian      themarvels  ...
# 2    la cosecha en enjambre  feria de editoriales ...
# 4    me encanta este video  guardianes de la galax...
# 5           oficialmente la mejor trilog a del ucm
# ...

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(10)
# Out:
# /tmp/ipykernel_31811/4219357815.py:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, row in tw_list['text'].iteritems():
#                                                     0  \
# 0   La mejor película post-Endgame junto con una d...
# 1   RT @zebazcr: Ni se estrena y ya la odian. 😂\n\...
# 2   RT @CristianRau9: La cosecha en Enjambre: feri...
# 4   👍me encanta este video: Guardianes de la Galax...
# 5   RT @Indie5051: Oficialmente la mejor trilogía ...
# 6   @Indie5051 Me impresiona darme cuenta que a mu...
# 7   El Capitán América del UCM  ya mola de por sí,...
# 9   @atletista1989 Y sabe mucho más de cómics que ...
# 10  RT @thxchosnone: Guardianes de la Galaxia tien...
# 11  RT @croquet_13: Btw, el Alto Evolucionador se ...
#
#                                                  text  polarity  subjectivity  \
# 0   la mejor pel cula post endgame junto con una d...       0.0           0.0
# ...

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# neutral     145       54.92
# positive     66       25.00
# negative     53       20.08

# %%
# create data for Pie Chart
pc = count_values_in_column(tw_list,"sentiment")
names= pc.index
size=pc["Percentage"]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','purple','orange'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
#Function to Create Wordcloud

def create_wordcloud(text):
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white", width=600, height=400,               
                  max_words=300,
                  stopwords=stopwords,
                  repeat=True)
    wc.generate(str(text))
    
    plt.imshow(wc)
    plt.show()

# %%
# Define the search term and the number of tweets to retrieve
search_words = "UCM"
num_tweets = 400

# Retrieve the tweets
tweets = tweepy.Cursor(twetterApi.search_tweets,
              q=search_words,
              lang="en").items(num_tweets)

# Perform sentiment analysis on the tweets and store the results in a list
sentiment_scores = []
for tweet in tweets:
    analysis = TextBlob(tweet.text)
    sentiment_scores.append(analysis.sentiment.polarity)

# Compute the overall sentiment score and print it to the console
overall_sentiment = sum(sentiment_scores) / len(sentiment_scores)
print("Overall sentiment score:", overall_sentiment)

# Plot the sentiment analysis
fig, ax = plt.subplots(figsize=(6, 6))
ax.hist(sentiment_scores, bins=[-1, -0.5, 0, 0.5, 1])
ax.set_title("Sentiment Analysis for Twitter")
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_xlabel("Sentiment Score")
ax.set_ylabel("Number of Tweets")
plt.show()
# Out:
# Overall sentiment score: 0.1929317899981963

# %%
#Creating wordcloud for all tweets
create_wordcloud(tw_list["text"].values)

# %%
#Creating wordcloud for positive sentiment
create_wordcloud(tw_list_positive["text"].values)

# %%
#Creating wordcloud for negative sentiment
create_wordcloud(tw_list_negative["text"].values)

# %%
#Creating wordcloud for neutral sentiment
create_wordcloud(tw_list_neutral["text"].values)
